# %%
# %pylab inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = sns.load_dataset("flights")

# %%
sns.relplot(x="passengers",y="month",hue="year",data=data)

# %%
data2 = sns.load_dataset("tips")

# %%
sns.relplot(x="time",y="tip",data=data2,kind="line")

# %%
sns.relplot(x="time",y="tip",data=data2)

# %%
sns.catplot(x="day",y="total_bill",data=data2,kind="boxen")

# %%
from scipy import stats

# %%
data3 = np.random.normal(loc=10,size=105,scale=2)
sns.distplot(data3)

# %%
iris = sns.load_dataset("iris")

g = sns.jointplot("sepal_width", "petal_length", data=iris,

                  kind="kde", space=0, color="g")
